# %% [markdown]
# # Bài 1
# Viết thêm vào chỗ các comment để function hoạt động
# tensor_1x2 = concat tensor_1 và tensor_2 (phải có preprocess với torch.squeeze())
# tensor_out = tích của tensor_1x2 và tensor_3 (bỏ đi 1 dimension)
# sum_bigger = tổng số lượng các phần tử trong tensor_out lớn hơn tensor_4

# %%
import torch
def function(input_value):
    tensor_1 = torch.randn(3, 1, 1, 255, 260, input_value)
    tensor_2 = torch.randn(3, 255, 260, 100)
    tensor_3 = torch.randn(3, 255, 260)
    tensor_4 = torch.randn(18, 500)

    tensor_1 = torch.squeeze(tensor_1, 1)
    tensor_1 = torch.squeeze(tensor_1, 1)
    tensor_1x2 = torch.concat((tensor_1, tensor_2), dim=-1)#concat tensor_1 and tensor_2
    tensor_out = torch.matmul(tensor_1x2, tensor_3)  #matmul tensor_1x2 and tensor_3
    # sum_bigger = #calculate number of value in tensor_out bigger than tensor_4

    # return sum_bigger.item()  

input_values = [3, 1]
for input_value in input_values:
    print(function(input_value))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# e:\BT\baitap\Torch_test\btap\Untitled-1.ipynb Cell 2' in <cell line: 17>()
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000001?line=15'>16</a> input_values = [3, 1]
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000001?line=16'>17</a> for input_value in input_values:
# ---> <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000001?line=17'>18</a>     print(function(input_value))
#
# e:\BT\baitap\Torch_test\btap\Untitled-1.ipynb Cell 2' in function(input_value)
#       <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000001?line=8'>9</a> tensor_1 = torch.squeeze(tensor_1, 1)
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000001?line=9'>10</a> tensor_1x2 = torch.concat((tensor_1, tensor_2), dim=-1)#concat tensor_1 and tensor_2
# ---> <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000001?line=10'>11</a> tensor_out = torch.matmul(tensor_1x2, tensor_3)
#
# RuntimeError: The size of tensor a (255) must match the size of tensor b (3) at non-singleton dimension 1

# %% [markdown]
# # Bài 2
# Tạo 1 class customer dataset là class con của Dataset có nhiệm vụ đọc thông tin từ file data.csv
# class dataset trả 3 thông tin name, title và label

# %%
from torch.utils.data import Dataset
import pandas as pd

class MyDataset(Dataset):
    def __init__(self, csv_file):
        super().__init__()
        self.lst = pd.read_csv(csv_file)

    def __len__(self):
        return int(self.lst.shape[0])
    
    def __getitem__(self, index):
        return self.lst['name'][index], self.lst['title'][index], self.lst['label'][index]

data = MyDataset('data.csv')
for items in data:
    print(items)
    # name, title, label = items
    # print(name, title, label)#ie Giang Giang coi 1
# Out:
# ('Giang', 'Giang coi', 1)
# ('Giang', 'Giang beo', 1)
# ('Hoang', 'sota', 1)
# ('Chien', 'dai gai', 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Admin\anaconda3\envs\datbt\lib\site-packages\pandas\core\indexes\range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/indexes/range.py?line=383'>384</a> try:
# --> <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/indexes/range.py?line=384'>385</a>     return self._range.index(new_key)
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/indexes/range.py?line=385'>386</a> except ValueError as err:
#
# ValueError: 4 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# e:\BT\baitap\Torch_test\btap\Untitled-1.ipynb Cell 4' in <cell line: 16>()
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000003?line=12'>13</a>         return self.lst['name'][index], self.lst['title'][index], self.lst['label'][index]
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000003?line=14'>15</a> data = MyDataset('data.csv')
# ---> <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000003?line=15'>16</a> for items in data:
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000003?line=16'>17</a>     print(items)
#
# e:\BT\baitap\Torch_test\btap\Untitled-1.ipynb Cell 4' in MyDataset.__getitem__(self, index)
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000003?line=11'>12</a> def __getitem__(self, index):
# ---> <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000003?line=12'>13</a>     return self.lst['name'][index], self.lst['title'][index], self.lst['label'][index]
#
# File c:\Users\Admin\anaconda3\envs\datbt\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=954'>955</a>     return self._values[key]
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=956'>957</a> elif key_is_scalar:
# --> <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=957'>958</a>     return self._get_value(key)
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=959'>960</a> if is_hashable(key):
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=960'>961</a>     # Otherwise index.get_value will raise InvalidIndexError
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=961'>962</a>     try:
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=962'>963</a>         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\Admin\anaconda3\envs\datbt\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=1065'>1066</a>     return self._values[label]
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=1067'>1068</a> # Similar to Index.get_value, but we do not fall back to positional
# -> <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=1068'>1069</a> loc = self.index.get_loc(label)
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/series.py?line=1069'>1070</a> return self.index._get_values_for_loc(self, loc, label)
#
# File c:\Users\Admin\anaconda3\envs\datbt\lib\site-packages\pandas\core\indexes\range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/indexes/range.py?line=384'>385</a>         return self._range.index(new_key)
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/indexes/range.py?line=385'>386</a>     except ValueError as err:
# --> <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/indexes/range.py?line=386'>387</a>         raise KeyError(key) from err
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/indexes/range.py?line=387'>388</a> self._check_indexing_error(key)
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/pandas/core/indexes/range.py?line=388'>389</a> raise KeyError(key)
#
# KeyError: 4

# %% [markdown]
# # Bài 3
# Xây dựng model theo cấu trúc dưới đây
# <img src="sample.png">

# %%
import torch
import torch.nn as nn
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=(3, 3),padding=1)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=(3, 3),padding=1)
        self.pool = nn.MaxPool2d(kernel_size=(2, 2),stride=2)
        self.relu = nn.ReLU()
        self.fc1 = nn.Linear(100352, 3)
    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool(x)
        x = x.reshape(x.shape[0], -1)
        x = self.fc1(x)
        return x

input = torch.randn(1, 3, 224, 224)
model = MyModel()
out = model(input)
print(out.shape) # Size 1, 3
# Out:
# torch.Size([1, 100352])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# e:\BT\baitap\Torch_test\btap\Untitled-1.ipynb Cell 6' in <cell line: 25>()
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000005?line=22'>23</a> input = torch.randn(1, 3, 224, 224)
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000005?line=23'>24</a> model = MyModel()
# ---> <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000005?line=24'>25</a> out = model(input)
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000005?line=25'>26</a> print(out.shape)
#
# File c:\Users\Admin\anaconda3\envs\datbt\lib\site-packages\torch\nn\modules\module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1105'>1106</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1106'>1107</a> # this function, and just call forward.
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1107'>1108</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1108'>1109</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1109'>1110</a>     return forward_call(*input, **kwargs)
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1110'>1111</a> # Do not call functions when jit is used
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1111'>1112</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# e:\BT\baitap\Torch_test\btap\Untitled-1.ipynb Cell 6' in MyModel.forward(self, x)
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000005?line=17'>18</a> x = x.reshape(x.shape[0], -1)
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000005?line=18'>19</a> print(x.shape)
# ---> <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000005?line=19'>20</a> x = self.fc1(x)
#      <a href='vscode-notebook-cell:/e%3A/BT/baitap/Torch_test/btap/Untitled-1.ipynb#ch0000005?line=20'>21</a> return x
#
# File c:\Users\Admin\anaconda3\envs\datbt\lib\site-packages\torch\nn\modules\module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1105'>1106</a> # If we don't have any hooks, we want to skip the rest of the logic in
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1106'>1107</a> # this function, and just call forward.
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1107'>1108</a> if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1108'>1109</a>         or _global_forward_hooks or _global_forward_pre_hooks):
# -> <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1109'>1110</a>     return forward_call(*input, **kwargs)
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1110'>1111</a> # Do not call functions when jit is used
#    <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/module.py?line=1111'>1112</a> full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Admin\anaconda3\envs\datbt\lib\site-packages\torch\nn\modules\linear.py:103, in Linear.forward(self, input)
#     <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/linear.py?line=101'>102</a> def forward(self, input: Tensor) -> Tensor:
# --> <a href='file:///c%3A/Users/Admin/anaconda3/envs/datbt/lib/site-packages/torch/nn/modules/linear.py?line=102'>103</a>     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x100352 and 93312x3)

# %% [markdown]
# # Bài 4
# Sửa model để trả về kết quả match với số lượng lớp của mình

# %%
import torch
import torch.nn as nn
from torchvision import models
class MyModel(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.network = models.resnet50()
        #Insert here

    def forward(self, x):
        return self.network(x)

input = torch.randn(1, 3, 224, 224)
model = MyModel(num_classes = 3)
out = model(input)
print(out.shape) # Size 1, 3
# Out:
# torch.Size([1, 1000])
